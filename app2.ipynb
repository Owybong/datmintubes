# %%
import pandas as pd

# %%
dt = pd.read_csv('listings.csv')

# %%
df = pd.DataFrame(dt)

# %%
pd.set_option('display.max_columns', None)
df.head()
# print(a.sum())
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0  275343  https://www.airbnb.com/rooms/275343  20241228025359   2024-12-28
# 1  275344  https://www.airbnb.com/rooms/275344  20241228025359   2024-12-28
# 2  294281  https://www.airbnb.com/rooms/294281  20241228025359   2024-12-28
# 3  324945  https://www.airbnb.com/rooms/324945  20241228025359   2024-12-28
# 4  330095  https://www.airbnb.com/rooms/330095  20241228025359   2024-12-28
#
#         source                                               name  \
# 0  city scrape   10min walk to MRT & a Cozy Room with window! (1)
# 1  city scrape              15 mins to Outram MRT Single Room (2)
# 2  city scrape                     5 mins walk from Newton subway
# 3  city scrape  Comfortable Room w/study area @ Redhill  MRT! (6)
# 4  city scrape  Relaxing Mini Room near Redhill MRT-NOwindow  (4)
#
#                                          description  \
# 0  **IMPORTANT NOTES:  READ BEFORE YOU BOOK! <br ...
# ...

# %%
room_type_counts = df['room_type'].value_counts()
print(room_type_counts)
# Out:
# Private room       1819
# Entire home/apt    1516
# Hotel room           85
# Shared room          27
# Name: room_type, dtype: int64

# %%
room_type_counts = df['property_type'].value_counts()
print(room_type_counts)
# Out:
# Private room in rental unit           791
# Entire serviced apartment             769
# Entire rental unit                    415
# Room in hotel                         268
# Private room in condo                 200
# Private room in home                  195
# Entire condo                          184
# Room in boutique hotel                117
# Private room in serviced apartment     91
# Entire home                            52
# Room in aparthotel                     51
# Private room in townhouse              40
# Private room in bungalow               34
# Private room in hostel                 29
# Private room in bed and breakfast      29
# Room in hostel                         28
# Entire loft                            25
# Private room in guesthouse             25
# Room in serviced apartment             15
# Private room in villa                  13
# Private room                           12
# Entire townhouse                        6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3447 entries, 0 to 3446
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            3447 non-null   int64
#  1   listing_url                                   3447 non-null   object
#  2   scrape_id                                     3447 non-null   int64
#  3   last_scraped                                  3447 non-null   object
#  4   source                                        3447 non-null   object
#  5   name                                          3447 non-null   object
#  6   description                                   3383 non-null   object
#  7   neighborhood_overview                         1921 non-null   object
#  8   picture_url                                   3447 non-null   object
# ...

# %%
filtered_df = df[df['neighbourhood_group_cleansed'] != 'Central Region'] 
needed_data = filtered_df[['price','number_of_reviews','review_scores_rating','availability_365']]
needed_data.to_csv('listing_updated.csv',index=False)

# %%
data = pd.read_csv('listing_updated.csv')
dfnya = pd.DataFrame(data)

# %%
tp = dfnya.dropna(subset="price")

tp.head()
# Out:
#       price  number_of_reviews  review_scores_rating  availability_365
# 0    $48.00                 60                  4.60               365
# 1    $60.00                 82                  4.69               244
# 7    $50.00                 10                  4.70               365
# 13  $200.00                369                  4.93               362
# 14   $60.00                 16                  4.81               239

# %%
tp.to_csv('listing_updated_cleaned.csv')
